# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# From the limit definition of a derivative: (defining f(x) = x^2, so the derivative should output as 2x)

# %%
def f(x):
  return x**2
h = 0.0001
x = 7.0
print((f(x + h) - f(x)) / h)
# Out:
# 14.000099999975646
